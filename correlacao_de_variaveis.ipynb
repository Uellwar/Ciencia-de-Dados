# %% [markdown]
# ### Introdução

# %% [markdown]
# Este Notebook propõe apresentar de maneira resumida as principais medidas de correlação entre variáveis

# %% [markdown]
# ### Coeficientes de Variacao

# %% [markdown]
# Uma pergunta que pode surgir em nossa análise exploratória é: O desvio padrão calculado é grande ou pequeno?
#
# Um desvio padrão pode ser considerado grande ou pequeno dependendo da ordem de grandeza da variável.
#
# Uma maneira de se expressar a variabilidade dos dados tirando a influência da ordem de grandeza da variável é através do coeficiente de variação, definido por:
#
# ![5.PNG](data:image/png;base64,...)

# %% [markdown]
# ###   Coeficientes de Correlação

# %% [markdown]
# Um coeficiente de correlação mede o grau pelo qual duas variáveis tendem a mudar juntas. O coeficiente descreve a força e a direção da relação.

# %% [markdown]
# ####   Correlação de Pearson

# %% [markdown]
# O coeficiente de correlação de Pearson é um teste que mede a relação estatística entre duas variáveis contínuas. Se a associação entre os elementos
# não for linear, o coeficiente não será representado adequadamente.
#
# O coeficiente de correlação de Pearson pode ter um intervalo de valores de +1 a -1.
#
# Um valor de 0 indica que não há associação entre as duas variáveis.
#
# Um valor maior que 0 indica uma associação positiva. Isto é, à medida que o valor de uma variável aumenta, o mesmo acontece com a outra variável.
#
# Um valor menor que 0 indica uma associação negativa. Isto é, à medida que o valor de uma variável aumenta, o valor da outra diminui.
#
# Para realizar a correlação de Pearson, é necessário cumprir o seguinte:
# 1. A escala de medição deve ser uma escala ou relação de intervalo;
# 2. As variáveis devem ser aproximadamente distribuídas;
# 3. A associação deve ser linear;
# 4. Não deve haver valores atípicos nos dados;

# %% [markdown]
# Fórmula da correlação de Pearson para dados **Populacionais**:
#
# ![6.PNG](data:image/png;base64,...)

# %% [markdown]
# Fórmula da correlação de Pearson para dados **Amostrais**:
#
# ![7.PNG](data:image/png;base64,...)
#
# Obs: R não possui dimensão, isto é, não depende da unidade de medida das variáveis X e Y.

# %% [markdown]
# Interpretando o resultado de r:
#
# • 0 a 0.3 positivo ou negativo indica uma correlação desprezível.
#
# • 0.3 a 0.5 positivo ou negativo indica uma correlação fraca.
#
# • 0.5 a 0.7 positivo ou negativo indica uma correlação moderada.
#
# • 0.7 a 0.9 positivo ou negativo indica uma correlação forte.
#
# • 0.9 para mais ou para menos indica uma correlação muito forte.

# %% [markdown]
# **Tipos de correlação entre 2 variáveis**:
#
# ![8.PNG](data:image/png;base64,...)

# %% [markdown]
# ####   Correlacao de Spearman

# %% [markdown]
# A correlação de Spearman avalia a relação **monotônica** entre duas variáveis contínuas ou ordinais.
#
# Em uma relação monotônica, as variáveis tendem a mudar juntas mas não necessariamente a uma taxa constante.
#
# O coeficiente de correlação de Spearman baseia-se nos valores classificados de cada variável, em vez de os dados brutos.
#
# A correlação de Spearman é muito usada para avaliar relações envolvendo variáveis ordinais. Por exemplo, você poderia usar a correlação de Spearman
# para avaliar se a ordem na qual os funcionários executam um teste está relacionada ao número de meses de emprego.

# %% [markdown]
# Fórmula da correlação de Spearman:
#
# ![9.PNG](data:image/png;base64,...)
#
# Onde:
#
# d = A diferença entre as fileiras das variáveis correspondentes
#
# n = Número de observações

# %% [markdown]
# Gráfico de relação monotônica:
#
# ![10.PNG](data:image/png;base64,...)

# %% [markdown]
# Comparação entre os coeficientes de Pearson e Spearman:
#
# Se a relação é que uma variável aumenta quando a outra aumenta mas a quantidade não é consistente, o coeficiente de correlação de Pearson é positivo mas menor que +1. O coeficiente de Spearman ainda será +1 neste caso.
#
# ![scatterplot_cubic_perfect_relationship.png](data:image/png;base64,...)
#
# Pearson = +0.851, Spearman = +1

# %% [markdown]
# Quando uma relação é aleatória ou inexistente, os dois coeficientes de correlação se aproximam de zero.
#
# ![12.PNG](data:image/png;base64,...)
#
#
# Pearson = −0.093, Spearman = −0,093

# %% [markdown]
# Se o relacionamento é aquela variável que diminui quando as outras aumentam, mas a quantidade não é consistente, então o coeficiente de correlação de
# Pearson é negativo, mas maior que -1. O coeficiente de Spearman ainda é igual a -1, neste caso.
#
# ![scatterplot_strictly_decreasing_exponential_relationship.png](data:image/png;base64,...)
#
# Pearson = −0.799, Spearman = −1

# %% [markdown]
# ### Coeficientes de Determinação

# %% [markdown]
# ####   Coeficiente R²

# %% [markdown]
# É a **porcentagem da variação** da variável resposta que é explicada por um modelo linear. Ou:
#
# R-quadrado = Variação explicada/Variação total
#
# O R-quadrado está sempre entre 0 e 100%:
#
# 0% indica que o modelo não explica nada da variabilidade dos dados de resposta ao redor de sua média.
#
# 100% indica que o modelo explica toda a variabilidade dos dados de resposta ao redor de sua média.

# %% [markdown]
# Caso R² = 0,62 (ou 62%):
#
# Cerca de 62% da variabilidade de y pode ser descrita (ou explicada) pela variabilidade de de X (Xi até Xn).
#
# O restante (38%) pode ser explicado por outros fatores não medidos.
#
# A inclusão de inúmeras variáveis, mesmo que tenham muito pouco poder explicativo sobre a variável dependente, aumentarão o valor de R².
#
# Isto incentiva a inclusão indiscriminada de variáveis, **prejudicando o princípio da parcimônia**.

# %% [markdown]
# **Princípio da parcimônia**:
#
# Grosso modo, o princípio postula que de múltiplas explicações adequadas e possíveis para o mesmo conjunto de fatos, **deve-se optar pela mais simples daquelas**.
#
# Por "simples" entende-se aquela que contiver o **menor número possível de variáveis e hipóteses** com relações lógicas entre si, das quais o
# fato a ser explicado segue logicamente.

# %% [markdown]
# Para combater esta tendência (de incluir muitas variáveis sem necessidade), podemos usar uma medida alternativa do coeficiente de determinação, que penaliza a inclusão de regressores pouco explicativos.
# Trata-se do **R² ajustado**.

# %% [markdown]
# Método para calcular R² Normalizado:
#
# ![13.PNG](data:image/png;base64,...)
#
# Onde:
#
# SQtot = Soma Total dos Quadrados Totais
#
# ![14.PNG](data:image/png;base64,...)
#
# onde n é o numero de observações.
#
# Partindo de que yi é o valor observado e y_barra é a média das observações, esta equação dá-nos a Soma Total dos Quadrados, ou seja,
# a soma dos quadrados das diferenças entre a média e cada valor observado.

# %% [markdown]
# SQres = Soma Total dos Quadrados Resíduos
#
# ![15.PNG](data:image/png;base64,...)
#
# Onde y^ é o valor estimado (previsão) de yi.
#
# Esta equação é a soma dos quadrados dos resíduos, que calcula a parte que não é explicada pelo modelo.

# %% [markdown]
# SQexp = Soma Total dos Quadrados Explicados
#
# ![16.PNG](data:image/png;base64,...)
#
# Onde y^ é o valor estimado (previsão) de yi.
#
# Esta equação, a soma dos quadrados explicada, indica-nos a diferença entre a média das observações e o valor estimado para cada observação,
# e soma os respectivos quadrados. Quanto menor for a diferença, maior poder explicativo detém o modelo.

# %% [markdown]
# ####   Coeficiente R² Ajustado

# %% [markdown]
# A inclusão de inúmeras variáveis, mesmo que tenham pouco poder explicativo sobre a variável dependente, aumentarão o valor de R².
#
# Isto incentiva a inclusão indiscriminada de variáveis, prejudicando o princípio da parcimônia.
#
# Para combater esta tendência, podemos usar uma medida alternativa do coeficiente de determinação, que penaliza a inclusão de regressores pouco explicativos.
#
# Trata-se do R² ajustado.
#
# ![17.PNG](data:image/png;base64,...)
#
# Obs: R² também é utilizado para comparação para avaliar o melhor entre dois modelos.
