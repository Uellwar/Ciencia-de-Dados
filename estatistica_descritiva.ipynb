# %% [markdown]
# ### Introdução

# %% [markdown]
# #### Este notebook tem o objetivo de apresentar um breve resumo sobre Estatística Descritiva, importância de cada resultado e a interpretação deles.

# %% [markdown]
# ###  Somatório

# %% [markdown]
# A notação de somatório (ou notação sigma **∑**) **nos permite escrever uma soma longa em uma única expressão**.
#
# ![02-1.png](data:image/png;base64,...)

# %% [markdown]
# ### Médias

# %% [markdown]
# #### Média Aritmética

# %% [markdown]
# A média aritmética simples é obtida **dividindo a soma de todos os valores que temos pela quantidade de valores**.
#
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# #### Média Ponderada

# %% [markdown]
# A média ponderada considera **'pesos'** para cada dado, onde cada um receberá um peso, respectivamente (p1, p2, p3, ..., pn).
# Cada item será multiplicado pelo seu peso. A média será dada pela divisão entre esta soma dos pesos com os dados e a soma dos pesos.
#
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# #### Média Armônica

# %% [markdown]
# A média harmônica de um conjunto de n dados é obtida dividindo a quantidade de dados pela soma dos inversos dos dados.
#
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# **Quando usar:**
# Quando trabalhamos com grandezas inversamente proporcionais, uma média interessante para a representação do conjunto de dados é a harmônica,
# que, junto à média aritmética e à média geométrica, é conhecida como média pitagórica. Situações como o cálculo de velocidade média
# são bastante comuns para o uso de média harmônica, e há problemas como de escoamento de água ou até mesmo de densidade que
# podem ser resolvidos por ela. A média harmônica é descrita como a quantidade total de elementos no conjunto, divida pela soma
# do inverso de cada elemento deste conjunto.

# %% [markdown]
# ### Desvio da Média

# %% [markdown]
# Estas medidas são capazes de nos dizer o quanto os dados (em média) estão distantes do valor médio (podemos usar outras medidas também) do conjunto de dados.

# %% [markdown]
# #### Variância

# %% [markdown]
# A variância de uma variável aleatória é uma medida da sua dispersão, indicando "o quão longe" em geral os seus valores se encontram do valor esperado.
# Se **μ = E(X)** é o valor esperado da variável aleatória X, então a variância é:
#
# Variância Populacional:
#
# ![007.png](data:image/png;base64,...)
#
#
# Variância Amostral:
#
# ![devio-padrao-formula-variante-matematica.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * **μ = E(X)** (lê-se, a média é o valor esperado do conjunto X)
#
# * Quando a amostra é pequena deve calcular-se a variância e
# o desvio padrão corrigidos. A única diferença é que se
# divide por (n-1) em vez de dividir por n

# %% [markdown]
# #### Desvio Padrão

# %% [markdown]
# Um grande desvio padrão indica que os pontos dos dados estão espalhados longe da média e um pequeno desvio padrão indica que os pontos
# dos dados estão agrupados perto da média.
#
# Tanto em probabilidade quanto em estatística, o desvio padrão é usado para expressar outros conceitos matemáticos importantes como o coeficiente de
# correlação, o coeficiente de variação ou a alocação ótima de Neyman, dentre outros.
#
# Desvio Padrão Populacional:
#
# ![08.PNG](data:image/png;base64,...)
#
# Desvio Padrão Amostral:
#
# ![13.png](data:image/png;base64,...)

# %% [markdown]
# ###  Moda

# %% [markdown]
# A moda de um conjunto de dados é definida como o valor de maior freqüência, isto é, o valor que mais se repete no conjunto de dados a ser analisado

# %% [markdown]
# ###  Mediana

# %% [markdown]
# Mediana é o valor que separa a metade maior e a metade menor de uma amostra, uma população ou uma distribuição de probabilidade.
# O conjunto deve estar previamente ordenado em ordem crescente ou decrescente.
# Caso o conjunto tiver um total de valores pares, então tira-se a média dos dois conjuntos que estão exatamente no meio (que estão na mediana) do conjunto.
#
# ![14.png](data:image/png;base64,...)

# %% [markdown]
# ###  Percentil e Quartil

# %% [markdown]
# #### Percentil

# %% [markdown]
# Em estatística descritiva, os percentis são medidas que dividem a amostra (por ordem crescente dos dados) em 100 partes, cada uma com uma percentagem
# de dados aproximadamente igual. O k-ésimo percentil Pk é o valor X (Xk) que corresponde à frequência cumulativa de **N*k/100** , onde N é o tamanho amostral.
#
# Portanto:
#
# O 1º percentil determina o 1% menor dos dados;
#
# O 98º percentil determina os 98% menores dos dados;
#
# O 25º percentil é o primeiro quartil;
#
# O 50º percentil é a mediana;
#
# De igual forma, o 10º percentil é o primeiro decil e o 80º percentil é o oitavo decil.
#
# ![distrib-normal.png](data:image/png;base64,...)

# %% [markdown]
# #### Quatil

# %% [markdown]
# Quartil é qualquer um dos três valores que divide o conjunto ordenado de dados em quatro partes iguais, e assim cada parte representa 1/4 da amostra ou população
#
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# ### Normalização

# %% [markdown]
# A normalização visa colocar os dados dentro de um padrão que facilite a sua análise. A normalização de dados Min-Max é um processo de
# transformar valores discrepantes usando uma escala que vai de 0,0 para o menor e 1,0 para o maior valor. Isso facilita a comparação de valores que
# foram medidos usando diferentes escalas, por exemplo, Celsius e Fahrenheit ou de diferentes unidades de medida como velocidade e distância.
#
# ![12.png](data:image/png;base64,...)
